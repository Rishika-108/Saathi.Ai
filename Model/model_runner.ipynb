# %%
# !pip install fastapi uvicorn pyngrok nest-asyncio transformers torch accelerate

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/model
# Out:
# /content/drive/MyDrive/model

# %%
# !ls
# Out:
# chat_safety_engine.py  peer_matching_engine.py	trajectory_engine.py
# journal_engine.py      __pycache__
# main.py		       requirements.txt

# %% [markdown]
# from journal_engine import analyze_journal
#
# result = analyze_journal(
#     "I feel anxious and lonely today"
# )
#
# print(result)

# %%
import sys
import os

# 1. Force the drive path into Python's search list
model_path = '/content/drive/MyDrive/model'
if model_path not in sys.path:
    sys.path.append(model_path)

# 2. Try a direct import to see the EXACT error
try:
    import main
    print("✅ Success! The 'main' module is importable.")
    print(f"Main file location: {main.__file__}")
except Exception as e:
    print("❌ Import Failed!")
    print(f"Error Type: {type(e).__name__}")
    print(f"Error Message: {str(e)}")
    import traceback
    traceback.print_exc()
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading sentiment model...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:103: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# ...

# %%
from pyngrok import ngrok

ngrok.set_auth_token("3DfqBmoWhYnNvn4G4mjHUh0dZ0J_6i6LtFpaq6x5ZERKZNSqQ")

# %%
import nest_asyncio
import uvicorn
from threading import Thread

nest_asyncio.apply()

def run():

    uvicorn.run(
        "main:app",
        host="0.0.0.0",
        port=8000
    )

thread = Thread(target=run)

thread.start()
# Out:
# INFO:     Started server process [16226]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# ERROR:    [Errno 98] error while attempting to bind on address ('0.0.0.0', 8000): address already in use
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.

# %%
public_url = ngrok.connect(8000)

print(public_url)
# Out:
# NgrokTunnel: "https://fossil-crinkle-cause.ngrok-free.dev" -> "http://localhost:8000"

# %%
import requests

response = requests.post(
    "https://fossil-crinkle-cause.ngrok-free.dev/chat/analyze",
    json={
        "text": "I feel stressed and overwhelmed"
    }
)

print(response.json())
# Out:
# INFO:     136.110.63.153:0 - "POST /chat/analyze HTTP/1.1" 200 OK
# {'stage': 'chat_analysis', 'analysis': {'message': 'I feel stressed and overwhelmed', 'emotion_distress': 2.1148475110530853, 'crisis_probability': 0.3645976483821869, 'toxic_probability': 0.19880254566669464, 'distress_score': 6.224443972110748, 'average_distress': 6.224443972110748, 'trend': 'stable', 'risk_level': 'high', 'action': 'suggest_support', 'memory_size': 2}}
